# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image
import scipy

# %%
# Load the trained model
model = tf.keras.models.load_model('vgg16.h5')

# %%
# Define the function to preprocess the image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224,224))
    image = tf.keras.preprocessing.image.img_to_array(image)
    image = tf.cast(image, tf.float32)/255.0
    image = tf.expand_dims(image, axis=0)
    #image = np.repeat(image, axis=0, repeats=None)
    return image

# Define the function to make a prediction
def predict_cancer(image_path):
    image = preprocess_image(image_path)
    prediction = model.predict(image)  #------------------>>>>>  [0]
    if prediction < 0.5:
        result = "The image does not contain cancer."
    else:
        result = "The image contains cancer."
    return result

    
    # Get the predicted class label
  #  predicted_class = np.argmax(predictions)
    
    # Get the predicted class name
  #  predicted_class_name = class_names[predicted_class]
    
  #  return predicted_class_name

# %%
# Define the function to handle button click event
def browse_file():
    file_path = filedialog.askopenfilename()
    if file_path:
        image = Image.open(file_path)
        image = image.resize((300, 300))
        photo = ImageTk.PhotoImage(image)
        image_label.config(image=photo)
        image_label.image = photo
        result = predict_cancer(file_path)
        result_label.config(text=result)
        print("Result label text:", result_label.cget("text"))
        
        
# Create the main window
window = tk.Tk()
window.title("Cancer Prediction")
window.geometry("500x500")

# Create the image label
image_label = tk.Label(window)
image_label.pack(pady=10)

# Create the browse button
browse_button = tk.Button(window, text="Browse", command=browse_file)
browse_button.pack(pady=10)

# Create the result label
result_label = tk.Label(window, font=('Arial', 14), text="Prediction will be displayed here !")
result_label.pack(pady=10)
# Start the main event loop
window.mainloop()
# Out:
# 1/1 [==============================] - 5s 5s/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 16ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 16ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 22ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 50ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 16ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 16ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 32ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 48ms/step
# Result label text: The image contains cancer.
# 1/1 [==============================] - 0s 16ms/step
# ...

# %%
#def open_file_dialog():
 #   file_path = filedialog.askopenfilename()
 #   if file_path:
 #       image = Image.open(file_path)
 #      image = image.resize((300, 300))
  #      image = ImageTk.PhotoImage(image)
  #      image_label.configure(image=image)
  #      image_label.image = image

#select_button = tk.Button(root, text="Select Image", command=open_file_dialog)
#select_button.pack()

# %%
#def analyze_image(images):
 #   preprocessed_image = preprocess_image(image)
  #  predictions = model.predict(preprocessed_image)
   # # Preprocess the image and pass it to your cancer detection model for analysis
    ## Display the results to the user
#
#analyze_button = tk.Button(root, text="Analyze Image", command=analyze_image)
#analyze_button.pack()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import numpy as np
import tensorflow as tf

# Load the trained model
model = tf.keras.models.load_model('cancer_prediction_model.h5')

# Define the function to preprocess the image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))
    image = image.convert('L')
    image = np.asarray(image, dtype=np.float32) / 255.0
    image = np.expand_dims(image, axis=0)
    return image

# Define the function to make a prediction
def predict_cancer(image_path):
    image = preprocess_image(image_path)
    prediction = model.predict(image)[0]
    if prediction < 0.5:
        result = "The image does not contain cancer."
    else:
        result = "The image contains cancer."
    return result

# Define the function to handle button click event
def browse_file():
    file_path = filedialog.askopenfilename()
    if file_path:
        image = Image.open(file_path)
        image = image.resize((300, 300))
        photo = ImageTk.PhotoImage(image)
        image_label.config(image=photo)
        image_label.image = photo
        result = predict_cancer(file_path)
        result_label.config(text=result)
        print("Result label text:", result_label.cget("text"))

# Create the main window
window = tk.Tk()
window.title("Cancer Prediction")
window.geometry("500x500")

# Create the image label
image_label = tk.Label(window)
image_label.pack(pady=10)

# Create the browse button
browse_button = tk.Button(window, text="Browse", command=browse_file)
browse_button.pack(pady=10)

# Create the result label
result_label = tk.Label(window, font=('Arial', 14), text="Please select an image to predict")
result_label.pack(pady=10)

# Start the main event loop
window.mainloop()
